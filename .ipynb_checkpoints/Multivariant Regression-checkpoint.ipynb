# %% [markdown]
# # Multivariant Regression

# %%
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.linear_model import Lasso
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

# %%
# %store -r final_df
final_df
# Out:
#      Temp  Humidity  Wind  Rain  ISI  Actual Fire
# 0     8.2      51.0   6.7   0.0  5.1          0.0
# 1    18.0      33.0   0.9   0.0  6.7          0.0
# 2    14.6      33.0   1.3   0.0  6.7          0.0
# 3     8.3      97.0   4.0   0.2  9.0          0.0
# 4    11.4      99.0   1.8   0.0  9.6          0.0
# ..    ...       ...   ...   ...  ...          ...
# 756  30.0      65.0  14.0   0.0  4.5          1.0
# 757  28.0      87.0  15.0   4.4  0.1          0.0
# 758  27.0      87.0  29.0   0.5  0.4          0.0
# 759  24.0      54.0  18.0   0.1  1.7          0.0
# 760  24.0      64.0  15.0   0.2  1.2          0.0
#
# [760 rows x 6 columns]

# %% [markdown]
# ## Assumptions
# The code below is to verify for regression assumptions and fit a line to the data. These assumptions include:
# - No multicollinearity
# - Homoscedasticity
# - No auto-correlation
# - Normal distribution of error

# %%
final_df.describe()
# Out:
#              Temp    Humidity        Wind        Rain         ISI  Actual Fire
# count  760.000000  760.000000  760.000000  760.000000  760.000000   760.000000
# mean    23.129868   49.964474    7.686974    0.258684    7.653421     0.535526
# std      8.088921   17.881842    5.778095    1.207761    4.860433     0.499065
# min      2.200000   15.000000    0.400000    0.000000    0.000000     0.000000
# 25%     17.600000   35.000000    3.100000    0.000000    4.100000     0.000000
# 50%     22.350000   47.000000    4.900000    0.000000    7.500000     1.000000
# 75%     30.000000   64.000000   14.000000    0.000000    9.800000     1.000000
# max     42.000000  100.000000   29.000000   16.800000   56.100000     1.000000

# %%
plt.figure(figsize=(20,17))
sns.heatmap(final_df.corr(),vmax=1, annot=True,cmap='viridis')
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
def create_vif(dataframe):
    ''' This function calculates the Variation Inflation Factors for each column and convert it into a dataframe'''
    
    #create an empty dataframe
    vif_table = pd.DataFrame()
    #populate the first column with the columns of the dataset
    vif_table['variables'] = dataframe.columns
    #calculate the VIF of each column and create a VIF column to store the number
    vif_table['VIF'] = [vif(dataframe.values, i) for i in range(dataframe.shape[1])]
    
    return vif_table

#print the VIF table for each variable
print(create_vif(final_df))
# Out:
#      variables        VIF
# 0         Temp  12.019131
# 1     Humidity   5.722884
# 2         Wind   6.916993
# 3         Rain   1.234704
# 4          ISI   3.850460
# 5  Actual Fire   2.357117

# %%
pairplot = sns.pairplot(final_df, diag_kind="hist",  corner=True)
pairplot.map_lower(sns.kdeplot, levels=4, color=".2")

# %%
final_df_remove_outliers = final_df[(np.abs(zscore(final_df)) < 3).all(axis=1)]

final_df.index.difference(final_df_remove_outliers.index)
# Out:
# Int64Index([ 11,  22, 266, 499, 519, 608, 609, 610, 621, 622, 633, 640, 655,
#             656, 657, 676, 735, 736, 757, 758],
#            dtype='int64')

# %%
pairplot = sns.pairplot(final_df_remove_outliers, diag_kind="hist",  corner=True)
pairplot.map_lower(sns.kdeplot, levels=4, color=".2")

# %% [markdown]
# From the scatter plot above we can see the types of relationships between our features and predictor. From this we mostly see little to no relationship meaning that fitting a regression line will be more of a challenge. We do see that the FFMC produces an inverse logistic curve while the Rain feature produces the same curve but reflected over the y axis. These two variables will have to be kept in mind. We also see one clear outlier that will need to be dealt with.

# %% [markdown]
# After fitting a line to the data we get an intercept of 10. This tells us that when every other feature is zero we will get a positive ISI value which makes sense. For example our temperature would be zero which wouldnt help any fire spread. As for the coefficients for our features they are all positive except for humidity. From our scatterplot we see a slightly negative relationship.

# %%
feature_cols = ['Temp', 'Humidity', 'Wind', 'Rain']
X = final_df_remove_outliers[feature_cols]
Y = final_df_remove_outliers.ISI

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.20, random_state=0)


# instantiate and fit
lm2 = Lasso()
lm2.fit(X_train, Y_train)

# print the coefficients
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# 11.902936103012077
# [ 0.03554795 -0.08179055 -0.14348684 -0.        ]

# %%
# Display results for each column
list(zip(feature_cols, lm2.coef_))
# Out:
# [('Temp', 0.03554795380756522),
#  ('Humidity', -0.08179054650720959),
#  ('Wind', -0.14348683795903971),
#  ('Rain', -0.0)]

# %%
# Predict values
y_predict = lm2.predict(X_test)

y_predict[:5]
# Out:
# array([6.66744334, 6.83035743, 8.34337127, 8.82575095, 6.56742777])

# %%
X2 = sm.add_constant(X)

lm1 = sm.OLS(Y,X2)

est = lm1.fit()
# Print the coefficients
est.params
# Out:
# C:\Users\Johnny\Documents\Anaconda\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# const       10.041341
# Temp         0.119546
# Humidity    -0.062136
# Wind        -0.235833
# Rain        -2.447404
# dtype: float64

# %%
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ISI   R-squared:                       0.279
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     71.24
# Date:                Sun, 31 Jul 2022   Prob (F-statistic):           5.24e-51
# Time:                        09:55:28   Log-Likelihood:                -2024.7
# No. Observations:                 740   AIC:                             4059.
# Df Residuals:                     735   BIC:                             4082.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.0413      0.686     14.630      0.000       8.694      11.389
# Temp           0.1195      0.025      4.793      0.000       0.071       0.169
# Humidity      -0.0621      0.010     -6.472      0.000      -0.081      -0.043
# Wind          -0.2358      0.041     -5.777      0.000      -0.316      -0.156
# Rain          -2.4474      0.353     -6.936      0.000      -3.140      -1.755
# ==============================================================================
# Omnibus:                       82.882   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              113.338
# Skew:                           0.839   Prob(JB):                     2.45e-25
# Kurtosis:                       3.927   Cond. No.                         288.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
figsize = plt.figure(figsize=(20, 10))
fig = sm.graphics.plot_regress_exog(est,
                                    'Temp',
                                    fig=figsize)

# %%
_,pval,_,fpval = sm.stats.diagnostic.het_white(est.resid, est.model.exog)
_,pval_pag,_,fpval_pag = sm.stats.diagnostic.het_breuschpagan(est.resid, est.model.exog)
print(pval,fpval)
print(pval_pag,fpval_pag)
# fail to reject that the variances for the errors are equal...Meaning we have no heteroscedasticity
# Out:
# 3.3126888941388993e-11 7.1292899717412786e-12
# 0.7420024474887205 0.7434787514418535

# %%
lag = min(10,(len(X)//5))
test_results = sm.stats.diagnostic.acorr_ljungbox(est.resid, lags= lag, return_df=True)
test_results
# Failed to reject null hypothesis so there is no auto correlation
# Out:
#        lb_stat     lb_pvalue
# 1    80.977644  2.282857e-19
# 2   107.693120  4.118473e-24
# 3   117.542526  2.610064e-25
# 4   127.152322  1.582328e-26
# 5   132.931819  5.678691e-27
# 6   138.087401  2.538041e-27
# 7   145.249386  4.033017e-28
# 8   152.941991  4.770387e-29
# 9   154.535198  1.012313e-28
# 10  154.691418  4.031499e-28

# %%
sm.qqplot(est.resid, line= 's')
mean_residuals = sum(est.resid) / len(est.resid)
mean_residuals
# Out:
# C:\Users\Johnny\Documents\Anaconda\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# 5.345873893708592e-15

# %% [markdown]
# Everything in model is working nicely

# %%
import math

model_mse = metrics.mean_squared_error(Y_test,y_predict)

model_mae = metrics.mean_absolute_error(Y_test,y_predict)

model_rmse = math.sqrt(model_mse)

print("MSE {:.3}".format(model_mse),"MAE {:.3}".format(model_mae),"RMSE {:.3}".format(model_rmse))
# Out:
# MSE 12.4 MAE 2.82 RMSE 3.51

# %%
model_r2 = metrics.r2_score(Y_test, y_predict)
model_r2
# Out:
# 0.32070116674388416

# %%
est.conf_int()
# Out:
#                  0          1
# const     8.693874  11.388809
# Temp      0.070578   0.168515
# Humidity -0.080985  -0.043287
# Wind     -0.315978  -0.155688
# Rain     -3.140170  -1.754638
