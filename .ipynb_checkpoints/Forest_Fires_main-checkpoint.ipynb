# %%
import pandas as pd
import plotly.graph_objects as go

# %%
df_algeria = pd.read_csv("C:/Users/Johnny/Downloads/Algerian_forest_fires_dataset_UPDATE.csv")

# %%
df_portugal = pd.read_csv("C:/Users/Johnny/Downloads/forestfires.csv")

# %%
df_algeria[0:-5]
# Out:
#                                                                         Bejaia Region Dataset
# day month year Temperature  RH  Ws Rain  FFMC DMC  DC    ISI  BUI  FWI               Classes
# 01  06    2012 29          57  18  0     65.7 3.4  7.6   1.3  3.4  0.5             not fire
# 02  06    2012 29          61  13  1.3   64.4 4.1  7.6   1    3.9  0.4             not fire
# 03  06    2012 26          82  22  13.1  47.1 2.5  7.1   0.3  2.7  0.1             not fire
# 04  06    2012 25          89  13  2.5   28.6 1.3  6.9   0    1.7  0               not fire
# ...                                                                                        ...
# 21  09    2012 35          34  17  0     92.2 23.6 97.3  13.8 29.4 21.6                fire
# 22  09    2012 33          64  13  0     88.9 26.1 106.3 7.1  32.4 13.7                fire
# 23  09    2012 35          56  14  0     89   29.4 115.6 7.5  36   15.2                fire
# 24  09    2012 26          49  6   2     61.3 11.9 28.1  0.6  11.9 0.4             not fire
# 25  09    2012 28          70  15  0     79.9 13.8 36.1  2.4  14.1 3               not fire
#
# [242 rows x 1 columns]

# %%
df_portugal[0:-5]
# Out:
#      X  Y month  day  FFMC    DMC     DC  ISI  temp  RH  wind  rain  area
# 0    7  5   mar  fri  86.2   26.2   94.3  5.1   8.2  51   6.7   0.0  0.00
# 1    7  4   oct  tue  90.6   35.4  669.1  6.7  18.0  33   0.9   0.0  0.00
# 2    7  4   oct  sat  90.6   43.7  686.9  6.7  14.6  33   1.3   0.0  0.00
# 3    8  6   mar  fri  91.7   33.3   77.5  9.0   8.3  97   4.0   0.2  0.00
# 4    8  6   mar  sun  89.3   51.3  102.2  9.6  11.4  99   1.8   0.0  0.00
# ..  .. ..   ...  ...   ...    ...    ...  ...   ...  ..   ...   ...   ...
# 507  2  4   aug  fri  91.0  166.9  752.6  7.1  25.9  41   3.6   0.0  0.00
# 508  1  2   aug  fri  91.0  166.9  752.6  7.1  25.9  41   3.6   0.0  0.00
# 509  5  4   aug  fri  91.0  166.9  752.6  7.1  21.1  71   7.6   1.4  2.17
# 510  6  5   aug  fri  91.0  166.9  752.6  7.1  18.2  62   5.4   0.0  0.43
# 511  8  6   aug  sun  81.6   56.7  665.6  1.9  27.8  35   2.7   0.0  0.00
#
# [512 rows x 13 columns]

# %% [markdown]
# ### Steps for EDA
# - Clean Names of columns
# - Check for Missing Values
# - Make algeria not fire fire column 0 and 1s
# - Make portgual area 0s and 1s
# - Plot some correlation plots
# - plot diff plots
# - Then create single df with all values

# %%
copy_df_algeria = df_algeria
copy_df_portugal = df_portugal

# %%
classes_list = copy_df_algeria['Bejaia Region Dataset ']
classes_list = classes_list.reset_index()
header = classes_list.iloc[0:]
header = header.loc[0]
classes_list.columns = header
copy_df_algeria = classes_list.iloc[1:]

# %%
copy_df_algeria = copy_df_algeria.drop(['day', 'month', 'year', 'BUI', 'FWI'], axis=1)

# %%
copy_df_algeria.columns = ['Temp', 'Humidity', 'Wind', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'Actual Fire']
copy_df_algeria = copy_df_algeria.drop([124])
copy_df_algeria
# Out:
#     Temp Humidity Wind  Rain  FFMC  DMC    DC  ISI   Actual Fire
# 1     29       57   18     0  65.7  3.4   7.6  1.3   not fire
# 2     29       61   13   1.3  64.4  4.1   7.6    1   not fire
# 3     26       82   22  13.1  47.1  2.5   7.1  0.3   not fire
# 4     25       89   13   2.5  28.6  1.3   6.9    0   not fire
# 5     27       77   16     0  64.8    3  14.2  1.2   not fire
# ..   ...      ...  ...   ...   ...  ...   ...  ...           ...
# 242   30       65   14     0  85.4   16  44.5  4.5       fire
# 243   28       87   15   4.4  41.1  6.5     8  0.1   not fire
# 244   27       87   29   0.5  45.9  3.5   7.9  0.4   not fire
# 245   24       54   18   0.1  79.7  4.3  15.2  1.7   not fire
# 246   24       64   15   0.2  67.3  3.8  16.5  1.2  not fire
#
# [245 rows x 9 columns]

# %%
copy_df_portugal = copy_df_portugal.drop(columns=['X', 'Y', 'month', 'day'], axis=1)

# %%
copy_df_portugal.columns = ['FFMC', 'DMC', 'DC', 'ISI', 'Temp', 'Humidity', 'Wind', 'Rain', 'Actual Fire']
copy_df_portugal = copy_df_portugal.reindex(columns = ['Temp', 'Humidity', 'Wind', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'Actual Fire'])
copy_df_portugal
# Out:
#      Temp  Humidity  Wind  Rain  FFMC    DMC     DC   ISI  Actual Fire
# 0     8.2        51   6.7   0.0  86.2   26.2   94.3   5.1         0.00
# 1    18.0        33   0.9   0.0  90.6   35.4  669.1   6.7         0.00
# 2    14.6        33   1.3   0.0  90.6   43.7  686.9   6.7         0.00
# 3     8.3        97   4.0   0.2  91.7   33.3   77.5   9.0         0.00
# 4    11.4        99   1.8   0.0  89.3   51.3  102.2   9.6         0.00
# ..    ...       ...   ...   ...   ...    ...    ...   ...          ...
# 512  27.8        32   2.7   0.0  81.6   56.7  665.6   1.9         6.44
# 513  21.9        71   5.8   0.0  81.6   56.7  665.6   1.9        54.29
# 514  21.2        70   6.7   0.0  81.6   56.7  665.6   1.9        11.16
# 515  25.6        42   4.0   0.0  94.4  146.0  614.7  11.3         0.00
# 516  11.8        31   4.5   0.0  79.5    3.0  106.7   1.1         0.00
#
# [517 rows x 9 columns]

# %%
copy_df_algeria['Actual Fire'] = copy_df_algeria['Actual Fire'].replace({'not fire   ': 0.0,'not fire    ': 0.0,'not fire':0.0,'not fire ':0.0, 'fire   ': 1.0, 'fire   ': 1.0, 'fire ':1.0})
for i in copy_df_algeria.columns:
    try:
        copy_df_algeria[i] = copy_df_algeria[i].astype(float)
    except:
        for j in copy_df_algeria[i].values:
            if type(j) == str:
                print(j)
                j = j[0:4]
                j = float(j)
#df.columns = df.columns.str.strip() 
# copy_df_algeria
# Out:
# 7.6
# 7.6
# 7.1
# 6.9
# 14.2
# 22.2
# 30.5
# 38.3
# 38.8
# 46.3
# 54.3
# 61.4
# 17
# 7.8
# 7.4
# 7.6
# 7.8
# 8
# 16
# 27.1
# 31.6
# 39.5
# 47.7
# 55.8
# 63.8
# 71.8
# 80.3
# 88.5
# 84.4
# 92.8
# 8.6
# 8.3
# 9.2
# 18.5
# 27.9
# 37
# 40.4
# 49.8
# 9.2
# 9.3
# 18.7
# 27.7
# 37.2
# 22.9
# 17
# 25.5
# 34.1
# 43.1
# 52.8
# 62.1
# 71.5
# 79.9
# 71.3
# 79.7
# 88.7
# 98.6
# 108.5
# 117.8
# 127
# 136
# 145.7
# 10.2
# 10
# 10
# 19.8
# 29.7
# 39.1
# 48.6
# 47
# 57
# 67
# 77
# 75.1
# 85.1
# 94.7
# 92.5
# 90.4
# 100.7
# 110.9
# 120.9
# 130.6
# 141.1
# 151.3
# 161.5
# 171.3
# 181.3
# 190.6
# 200.2
# 210.4
# 220.4
# 180.4
# 8.7
# 7.5
# 7
# 7.5
# 15.7
# 24
# 32.2
# 30.1
# 8.4
# 8.4
# 8.9
# 8.4
# 16.6
# 7.5
# 7
# 7.3
# 15.7
# 24.3
# 33.1
# 41.3
# 49.3
# 57.9
# 41.4
# 30.4
# 15.2
# 7.7
# 16.3
# 24.9
# 8.8
# 7.7
# 7.5
# 8.2
# 7.8
# 7.6
# 15.4
# 17.6
# 26.3
# 28.9
# 7.4
# 14.7
# 22.5
# 30.5
# 37.8
# 7.8
# 7.3
# 14.7
# 8
# 8
# 8.3
# 8.2
# 8
# 18.4
# 8.3
# 8.3
# 17
# 25.6
# 34.5
# 43.3
# 52.4
# 36.7
# 8.5
# 8.5
# 17.8
# 27.3
# 36.8
# 46.4
# 45.1
# 35.4
# 9.7
# 9.9
# 9.5
# 9.5
# 19.4
# 10.4
# 14.6 9
# 24.1
# 33.1
# 42.3
# 51.6
# 61.1
# 71
# 80.6
# 90.1
# 99
# 56.6
# 15.9
# 19.7
# 28.3
# 37.6
# 47.2
# 57.1
# 67.2
# 10.5
# 21.4
# 32.1
# 42.7
# 52.5
# 9.1
# 9.8
# 20.2
# 30.9
# 35.4
# 46.3
# 41.5
# 45.1
# 55.5
# 54.2
# 65.1
# 76.4
# 86.8
# 96.8
# 107
# 117.1
# 127.5
# 137.7
# 147.7
# 157.5
# 167.2
# 177.3
# 166
# 149.2
# 159.1
# 168.2
# 8.2
# 16.3
# 24.3
# 26.6
# 8.4
# 9.1
# 17.7
# 26.1
# 34.5
# 8.2
# 16.6
# 25.2
# 33.4
# 41.5
# 50.2
# 59.2
# 63.3
# 77.8
# 86
# 88
# 97.3
# 106.3
# 115.6
# 28.1
# 36.1
# 44.5
# 8
# 7.9
# 15.2
# 16.5
# not fire
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3092/1121333398.py in <module>
#       3     try:
# ----> 4         copy_df_algeria[i] = copy_df_algeria[i].astype(float)
#       5     except:
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#
# ValueError: could not convert string to float: 'not fire     '
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3092/1121333398.py in <module>
#       8                 print(j)
#       9                 j = j[0:4]
# ---> 10                 j = float(j)
#      11 # copy_df_algeria
#
# ValueError: could not convert string to float: 'not '
